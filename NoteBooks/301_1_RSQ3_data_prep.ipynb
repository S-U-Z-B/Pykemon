# %% [markdown]
# # Data Prep For RSQ3: Abilities and Types Columns

# %% [markdown]
# RSQ3 - Main Question: Which individual Pokémon has the highest individual stat for each category?
#
# Sub questions: Which **types** of Pokémon have the highest base stat totals? Do **abilities** factor into a pokémons strength?
#
# In this notebook, I am preparing the **abilities and types columns** so that the sub questions are more manageable later on when I need to analyse this data.

# %% [markdown]
# ## Task 1: Imports and Local File

# %% [markdown]
# Below are the necessary imports needed for this notebook.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# I turn the saved local csv file, which contains every pokemon and their details which I had gathered by calling from the API, to a dataframe.
#
# This raw dataframe will be edited so that the information is more accessible. For this notebook, I will edit the 'abilities' and 'types' columns as they will be needed for the sub questions.

# %%
df_poke_raw = pd.read_csv("301_all_pokemon_data.csv")
df_poke_raw
# Out:
#                                              abilities  base_experience  \
# 0    [{'ability': {'name': 'overgrow', 'url': 'http...               64
# 1    [{'ability': {'name': 'overgrow', 'url': 'http...              142
# 2    [{'ability': {'name': 'overgrow', 'url': 'http...              236
# 3    [{'ability': {'name': 'blaze', 'url': 'https:/...               62
# 4    [{'ability': {'name': 'blaze', 'url': 'https:/...              142
# ..                                                 ...              ...
# 893  [{'ability': {'name': 'transistor', 'url': 'ht...              290
# 894  [{'ability': {'name': 'dragons-maw', 'url': 'h...              290
# 895  [{'ability': {'name': 'chilling-neigh', 'url':...              290
# 896  [{'ability': {'name': 'grim-neigh', 'url': 'ht...              290
# 897  [{'ability': {'name': 'unnerve', 'url': 'https...              250
#
#                                                  forms  \
# 0    [{'name': 'bulbasaur', 'url': 'https://pokeapi...
# 1    [{'name': 'ivysaur', 'url': 'https://pokeapi.c...
# 2    [{'name': 'venusaur', 'url': 'https://pokeapi....
# 3    [{'name': 'charmander', 'url': 'https://pokeap...
# 4    [{'name': 'charmeleon', 'url': 'https://pokeap...
# ..                                                 ...
# 893  [{'name': 'regieleki', 'url': 'https://pokeapi...
# 894  [{'name': 'regidrago', 'url': 'https://pokeapi...
# 895  [{'name': 'glastrier', 'url': 'https://pokeapi...
# 896  [{'name': 'spectrier', 'url': 'https://pokeapi...
# 897  [{'name': 'calyrex', 'url': 'https://pokeapi.c...
#
#                                           game_indices  height held_items  \
# 0    [{'game_index': 153, 'version': {'name': 'red'...       7         []
# 1    [{'game_index': 9, 'version': {'name': 'red', ...      10         []
# 2    [{'game_index': 154, 'version': {'name': 'red'...      20         []
# 3    [{'game_index': 176, 'version': {'name': 'red'...       6         []
# 4    [{'game_index': 178, 'version': {'name': 'red'...      11         []
# ..                                                 ...     ...        ...
# 893                                                 []      12         []
# 894                                                 []      21         []
# 895                                                 []      22         []
# 896                                                 []      20         []
# 897                                                 []      11         []
#
#       id  is_default                          location_area_encounters  \
# 0      1        True    https://pokeapi.co/api/v2/pokemon/1/encounters
# 1      2        True    https://pokeapi.co/api/v2/pokemon/2/encounters
# 2      3        True    https://pokeapi.co/api/v2/pokemon/3/encounters
# 3      4        True    https://pokeapi.co/api/v2/pokemon/4/encounters
# 4      5        True    https://pokeapi.co/api/v2/pokemon/5/encounters
# ..   ...         ...                                               ...
# 893  894        True  https://pokeapi.co/api/v2/pokemon/894/encounters
# 894  895        True  https://pokeapi.co/api/v2/pokemon/895/encounters
# 895  896        True  https://pokeapi.co/api/v2/pokemon/896/encounters
# 896  897        True  https://pokeapi.co/api/v2/pokemon/897/encounters
# 897  898        True  https://pokeapi.co/api/v2/pokemon/898/encounters
#
#                                                  moves        name  order  \
# 0    [{'move': {'name': 'razor-wind', 'url': 'https...   bulbasaur      1
# 1    [{'move': {'name': 'swords-dance', 'url': 'htt...     ivysaur      2
# 2    [{'move': {'name': 'swords-dance', 'url': 'htt...    venusaur      3
# 3    [{'move': {'name': 'mega-punch', 'url': 'https...  charmander      5
# 4    [{'move': {'name': 'mega-punch', 'url': 'https...  charmeleon      6
# ..                                                 ...         ...    ...
# 893                                                 []   regieleki     -1
# 894                                                 []   regidrago     -1
# 895                                                 []   glastrier     -1
# 896                                                 []   spectrier     -1
# 897                                                 []     calyrex     -1
#
#     past_types                                            species  \
# 0           []  {'name': 'bulbasaur', 'url': 'https://pokeapi....
# 1           []  {'name': 'ivysaur', 'url': 'https://pokeapi.co...
# 2           []  {'name': 'venusaur', 'url': 'https://pokeapi.c...
# 3           []  {'name': 'charmander', 'url': 'https://pokeapi...
# 4           []  {'name': 'charmeleon', 'url': 'https://pokeapi...
# ..         ...                                                ...
# 893         []  {'name': 'regieleki', 'url': 'https://pokeapi....
# 894         []  {'name': 'regidrago', 'url': 'https://pokeapi....
# 895         []  {'name': 'glastrier', 'url': 'https://pokeapi....
# 896         []  {'name': 'spectrier', 'url': 'https://pokeapi....
# 897         []  {'name': 'calyrex', 'url': 'https://pokeapi.co...
#
#                                                sprites  \
# 0    {'back_default': 'https://raw.githubuserconten...
# 1    {'back_default': 'https://raw.githubuserconten...
# 2    {'back_default': 'https://raw.githubuserconten...
# 3    {'back_default': 'https://raw.githubuserconten...
# 4    {'back_default': 'https://raw.githubuserconten...
# ..                                                 ...
# 893  {'back_default': 'https://raw.githubuserconten...
# 894  {'back_default': 'https://raw.githubuserconten...
# 895  {'back_default': 'https://raw.githubuserconten...
# 896  {'back_default': 'https://raw.githubuserconten...
# 897  {'back_default': 'https://raw.githubuserconten...
#
#                                                  stats  \
# 0    [{'base_stat': 45, 'effort': 0, 'stat': {'name...
# 1    [{'base_stat': 60, 'effort': 0, 'stat': {'name...
# 2    [{'base_stat': 80, 'effort': 0, 'stat': {'name...
# 3    [{'base_stat': 39, 'effort': 0, 'stat': {'name...
# 4    [{'base_stat': 58, 'effort': 0, 'stat': {'name...
# ..                                                 ...
# 893  [{'base_stat': 80, 'effort': 0, 'stat': {'name...
# 894  [{'base_stat': 200, 'effort': 3, 'stat': {'nam...
# 895  [{'base_stat': 100, 'effort': 0, 'stat': {'nam...
# 896  [{'base_stat': 100, 'effort': 0, 'stat': {'nam...
# 897  [{'base_stat': 100, 'effort': 3, 'stat': {'nam...
#
#                                                  types  weight
# 0    [{'slot': 1, 'type': {'name': 'grass', 'url': ...      69
# 1    [{'slot': 1, 'type': {'name': 'grass', 'url': ...     130
# 2    [{'slot': 1, 'type': {'name': 'grass', 'url': ...    1000
# 3    [{'slot': 1, 'type': {'name': 'fire', 'url': '...      85
# 4    [{'slot': 1, 'type': {'name': 'fire', 'url': '...     190
# ..                                                 ...     ...
# 893  [{'slot': 1, 'type': {'name': 'electric', 'url...    1450
# 894  [{'slot': 1, 'type': {'name': 'dragon', 'url':...    2000
# 895  [{'slot': 1, 'type': {'name': 'ice', 'url': 'h...    8000
# 896  [{'slot': 1, 'type': {'name': 'ghost', 'url': ...     445
# 897  [{'slot': 1, 'type': {'name': 'psychic', 'url'...      77
#
# [898 rows x 18 columns]

# %% [markdown]
# ## Task 2: Abilities

# %% [markdown]
# In the first column of the raw dataframe we have Abilities. **Abilities have various effects when used in a battle that can either help or hinder a player.** In Pokémon, a pokémon has at least one ability but can also have an optional second or 'hidden' ability as well.
#
# Currently, each index contains all abilities which would make it difficult when it is needed later on. So, I created 3 empty lists for each category and will join them to the raw dataframe.

# %%
#empty list to hold ability types
ability_res = []
ability_res_2 = []
hidden_res = []

for x in range(898):
    ab_res = df_poke_raw["abilities"][x]
    #turns the dataframe column into a list, making it possible to loop through abilities
    ab_res = eval(ab_res)
    
    #loops through abilities
    for ability in ab_res:
        #gets the name of the ability
        res = ability["ability"]
        res = res["name"]
        #if statements that count the number of abilities per pokemon:
        #if theres only 1 ability, we simply add it to the First Ability column and leave the other columns empty
        if len(ab_res) == 1:
            ability_res.append(res)
            ability_res_2.append(np.nan)
            hidden_res.append(np.nan)
            
        #if theres 2 abilities, 2 scenarios occur
        if len(ab_res) == 2:
            #1) pokemon has 2 abilities (slot 1 + 2)
            if ability["slot"] == 1:
                ability_res.append(res) 
            if ability["slot"] == 2:
                ability_res_2.append(res)
                hidden_res.append(np.nan)
            #2) pokemon has 1 ability and 1 hidden ability (slot 1 + 3)
            if ability["slot"] == 3:
                ability_res_2.append(np.nan)
                hidden_res.append(res)
                
        #all 3 columns are appended    
        if len(ab_res) == 3:
            if ability["slot"] == 1:
                ability_res.append(res) 
            if ability["slot"] == 2:
                ability_res_2.append(res)
            if ability["slot"] == 3:
                hidden_res.append(res)

# %% [markdown]
# I turn the 3 ability lists into a single zipped list. I then make this into a dataframe and label the columns.

# %%
zippedList =  list(zip(ability_res, ability_res_2, hidden_res))

# %%
df_abilities = pd.DataFrame(zippedList, columns = ['ABILITY1', 'ABILITY2', 'HIDDEN_ABILITY'])
df_abilities
# Out:
#            ABILITY1 ABILITY2 HIDDEN_ABILITY
# 0          overgrow      NaN    chlorophyll
# 1          overgrow      NaN    chlorophyll
# 2          overgrow      NaN    chlorophyll
# 3             blaze      NaN    solar-power
# 4             blaze      NaN    solar-power
# ..              ...      ...            ...
# 893      transistor      NaN            NaN
# 894     dragons-maw      NaN            NaN
# 895  chilling-neigh      NaN            NaN
# 896      grim-neigh      NaN            NaN
# 897         unnerve      NaN            NaN
#
# [898 rows x 3 columns]

# %% [markdown]
# I then filled the empty columns so that they say 'none' rather than NaN for better formatting.

# %%
df_abilities = df_abilities.fillna("none")
df_abilities
# Out:
#            ABILITY1 ABILITY2 HIDDEN_ABILITY
# 0          overgrow     none    chlorophyll
# 1          overgrow     none    chlorophyll
# 2          overgrow     none    chlorophyll
# 3             blaze     none    solar-power
# 4             blaze     none    solar-power
# ..              ...      ...            ...
# 893      transistor     none           none
# 894     dragons-maw     none           none
# 895  chilling-neigh     none           none
# 896      grim-neigh     none           none
# 897         unnerve     none           none
#
# [898 rows x 3 columns]

# %% [markdown]
# Next, I join the dataframe with the 3 ability columns to the raw dataframe and then delete the original 'abilities' column since it is no longer necessary now that we filitered the needed information from it.

# %%
df_poke_ab = df_poke_raw.join(
    df_abilities, 
    how='inner'
)
df_poke_ab
# Out:
#                                              abilities  base_experience  \
# 0    [{'ability': {'name': 'overgrow', 'url': 'http...               64
# 1    [{'ability': {'name': 'overgrow', 'url': 'http...              142
# 2    [{'ability': {'name': 'overgrow', 'url': 'http...              236
# 3    [{'ability': {'name': 'blaze', 'url': 'https:/...               62
# 4    [{'ability': {'name': 'blaze', 'url': 'https:/...              142
# ..                                                 ...              ...
# 893  [{'ability': {'name': 'transistor', 'url': 'ht...              290
# 894  [{'ability': {'name': 'dragons-maw', 'url': 'h...              290
# 895  [{'ability': {'name': 'chilling-neigh', 'url':...              290
# 896  [{'ability': {'name': 'grim-neigh', 'url': 'ht...              290
# 897  [{'ability': {'name': 'unnerve', 'url': 'https...              250
#
#                                                  forms  \
# 0    [{'name': 'bulbasaur', 'url': 'https://pokeapi...
# 1    [{'name': 'ivysaur', 'url': 'https://pokeapi.c...
# 2    [{'name': 'venusaur', 'url': 'https://pokeapi....
# 3    [{'name': 'charmander', 'url': 'https://pokeap...
# 4    [{'name': 'charmeleon', 'url': 'https://pokeap...
# ..                                                 ...
# 893  [{'name': 'regieleki', 'url': 'https://pokeapi...
# 894  [{'name': 'regidrago', 'url': 'https://pokeapi...
# 895  [{'name': 'glastrier', 'url': 'https://pokeapi...
# 896  [{'name': 'spectrier', 'url': 'https://pokeapi...
# 897  [{'name': 'calyrex', 'url': 'https://pokeapi.c...
#
#                                           game_indices  height held_items  \
# 0    [{'game_index': 153, 'version': {'name': 'red'...       7         []
# 1    [{'game_index': 9, 'version': {'name': 'red', ...      10         []
# 2    [{'game_index': 154, 'version': {'name': 'red'...      20         []
# 3    [{'game_index': 176, 'version': {'name': 'red'...       6         []
# 4    [{'game_index': 178, 'version': {'name': 'red'...      11         []
# ..                                                 ...     ...        ...
# 893                                                 []      12         []
# 894                                                 []      21         []
# 895                                                 []      22         []
# 896                                                 []      20         []
# 897                                                 []      11         []
#
#       id  is_default                          location_area_encounters  \
# 0      1        True    https://pokeapi.co/api/v2/pokemon/1/encounters
# 1      2        True    https://pokeapi.co/api/v2/pokemon/2/encounters
# 2      3        True    https://pokeapi.co/api/v2/pokemon/3/encounters
# 3      4        True    https://pokeapi.co/api/v2/pokemon/4/encounters
# 4      5        True    https://pokeapi.co/api/v2/pokemon/5/encounters
# ..   ...         ...                                               ...
# 893  894        True  https://pokeapi.co/api/v2/pokemon/894/encounters
# 894  895        True  https://pokeapi.co/api/v2/pokemon/895/encounters
# 895  896        True  https://pokeapi.co/api/v2/pokemon/896/encounters
# 896  897        True  https://pokeapi.co/api/v2/pokemon/897/encounters
# 897  898        True  https://pokeapi.co/api/v2/pokemon/898/encounters
#
#                                                  moves  ... order  past_types  \
# 0    [{'move': {'name': 'razor-wind', 'url': 'https...  ...     1          []
# 1    [{'move': {'name': 'swords-dance', 'url': 'htt...  ...     2          []
# 2    [{'move': {'name': 'swords-dance', 'url': 'htt...  ...     3          []
# 3    [{'move': {'name': 'mega-punch', 'url': 'https...  ...     5          []
# 4    [{'move': {'name': 'mega-punch', 'url': 'https...  ...     6          []
# ..                                                 ...  ...   ...         ...
# 893                                                 []  ...    -1          []
# 894                                                 []  ...    -1          []
# 895                                                 []  ...    -1          []
# 896                                                 []  ...    -1          []
# 897                                                 []  ...    -1          []
#
#                                                species  \
# 0    {'name': 'bulbasaur', 'url': 'https://pokeapi....
# 1    {'name': 'ivysaur', 'url': 'https://pokeapi.co...
# 2    {'name': 'venusaur', 'url': 'https://pokeapi.c...
# 3    {'name': 'charmander', 'url': 'https://pokeapi...
# 4    {'name': 'charmeleon', 'url': 'https://pokeapi...
# ..                                                 ...
# 893  {'name': 'regieleki', 'url': 'https://pokeapi....
# 894  {'name': 'regidrago', 'url': 'https://pokeapi....
# 895  {'name': 'glastrier', 'url': 'https://pokeapi....
# 896  {'name': 'spectrier', 'url': 'https://pokeapi....
# 897  {'name': 'calyrex', 'url': 'https://pokeapi.co...
#
#                                                sprites  \
# 0    {'back_default': 'https://raw.githubuserconten...
# 1    {'back_default': 'https://raw.githubuserconten...
# 2    {'back_default': 'https://raw.githubuserconten...
# 3    {'back_default': 'https://raw.githubuserconten...
# 4    {'back_default': 'https://raw.githubuserconten...
# ..                                                 ...
# 893  {'back_default': 'https://raw.githubuserconten...
# 894  {'back_default': 'https://raw.githubuserconten...
# 895  {'back_default': 'https://raw.githubuserconten...
# 896  {'back_default': 'https://raw.githubuserconten...
# 897  {'back_default': 'https://raw.githubuserconten...
#
#                                                  stats  \
# 0    [{'base_stat': 45, 'effort': 0, 'stat': {'name...
# 1    [{'base_stat': 60, 'effort': 0, 'stat': {'name...
# 2    [{'base_stat': 80, 'effort': 0, 'stat': {'name...
# 3    [{'base_stat': 39, 'effort': 0, 'stat': {'name...
# 4    [{'base_stat': 58, 'effort': 0, 'stat': {'name...
# ..                                                 ...
# 893  [{'base_stat': 80, 'effort': 0, 'stat': {'name...
# 894  [{'base_stat': 200, 'effort': 3, 'stat': {'nam...
# 895  [{'base_stat': 100, 'effort': 0, 'stat': {'nam...
# 896  [{'base_stat': 100, 'effort': 0, 'stat': {'nam...
# 897  [{'base_stat': 100, 'effort': 3, 'stat': {'nam...
#
#                                                  types weight        ABILITY1  \
# 0    [{'slot': 1, 'type': {'name': 'grass', 'url': ...     69        overgrow
# 1    [{'slot': 1, 'type': {'name': 'grass', 'url': ...    130        overgrow
# 2    [{'slot': 1, 'type': {'name': 'grass', 'url': ...   1000        overgrow
# 3    [{'slot': 1, 'type': {'name': 'fire', 'url': '...     85           blaze
# 4    [{'slot': 1, 'type': {'name': 'fire', 'url': '...    190           blaze
# ..                                                 ...    ...             ...
# 893  [{'slot': 1, 'type': {'name': 'electric', 'url...   1450      transistor
# 894  [{'slot': 1, 'type': {'name': 'dragon', 'url':...   2000     dragons-maw
# 895  [{'slot': 1, 'type': {'name': 'ice', 'url': 'h...   8000  chilling-neigh
# 896  [{'slot': 1, 'type': {'name': 'ghost', 'url': ...    445      grim-neigh
# 897  [{'slot': 1, 'type': {'name': 'psychic', 'url'...     77         unnerve
#
#     ABILITY2 HIDDEN_ABILITY
# 0       none    chlorophyll
# 1       none    chlorophyll
# 2       none    chlorophyll
# 3       none    solar-power
# 4       none    solar-power
# ..       ...            ...
# 893     none           none
# 894     none           none
# 895     none           none
# 896     none           none
# 897     none           none
#
# [898 rows x 21 columns]

# %%
df_poke_ab = df_poke_ab.drop(columns = "abilities")

# %% [markdown]
# ## Task 3 : Types

# %% [markdown]
# Next, I will simplify the Type column. In Pokémon, any pokémon can have either 1 or 2 types. In the game, **types are properties every pokémon possesses which affects gameplay.** For example in a battle between a water-type and a fire-type pokémon, a water-type can cause more damage since fire-types are weak against them.
#
# Similar to abilities, I create 2 empty lists to hold the types for each pokémon. I then put the appended lists into a zipped list and finally put it into a dataframe.

# %%
#empty lists to hold all types
type_list_res = []
type_list_res_2 = []

for x in range(898):
    type_res = df_poke_raw["types"][x]
    #turns the dataframe column into a list, making it possible to loop through every pokemon
    type_res = eval(type_res)
    #loops through each pokemons type
    for types in type_res:
        res = types["type"]
        res = res["name"]
        
        #Scenario 1) a pokemon with only 1 type
        if len(type_res) == 1:
            type_list_res.append(res)
            type_list_res_2.append(np.nan)
        
        #Scenario 2) a pokemon with 2 types
        if len(type_res) == 2:
            if types["slot"] == 1:
                type_list_res.append(res) 
            if types["slot"] == 2:
                type_list_res_2.append(res)

# %%
zippedList =  list(zip(type_list_res, type_list_res_2))
df_type = pd.DataFrame(zippedList, columns = ['TYPE1', 'TYPE2'])
df_type
# Out:
#         TYPE1   TYPE2
# 0       grass  poison
# 1       grass  poison
# 2       grass  poison
# 3        fire     NaN
# 4        fire     NaN
# ..        ...     ...
# 893  electric     NaN
# 894    dragon     NaN
# 895       ice     NaN
# 896     ghost     NaN
# 897   psychic   grass
#
# [898 rows x 2 columns]

# %%
df_type = df_type.fillna("none")
df_type
# Out:
#         TYPE1   TYPE2
# 0       grass  poison
# 1       grass  poison
# 2       grass  poison
# 3        fire    none
# 4        fire    none
# ..        ...     ...
# 893  electric    none
# 894    dragon    none
# 895       ice    none
# 896     ghost    none
# 897   psychic   grass
#
# [898 rows x 2 columns]

# %% [markdown]
# I join the 2 type columns to the edited dataframe. This new dataframe will now contain the edited columns for abilities and types. I no longer need the original 'types' column now that I have added these columns, so I delete this as well.

# %%
df_poke_ab_type = df_poke_ab.join(
    df_type, 
    how='inner'
)
df_poke_ab_type
# Out:
#      base_experience                                              forms  \
# 0                 64  [{'name': 'bulbasaur', 'url': 'https://pokeapi...
# 1                142  [{'name': 'ivysaur', 'url': 'https://pokeapi.c...
# 2                236  [{'name': 'venusaur', 'url': 'https://pokeapi....
# 3                 62  [{'name': 'charmander', 'url': 'https://pokeap...
# 4                142  [{'name': 'charmeleon', 'url': 'https://pokeap...
# ..               ...                                                ...
# 893              290  [{'name': 'regieleki', 'url': 'https://pokeapi...
# 894              290  [{'name': 'regidrago', 'url': 'https://pokeapi...
# 895              290  [{'name': 'glastrier', 'url': 'https://pokeapi...
# 896              290  [{'name': 'spectrier', 'url': 'https://pokeapi...
# 897              250  [{'name': 'calyrex', 'url': 'https://pokeapi.c...
#
#                                           game_indices  height held_items  \
# 0    [{'game_index': 153, 'version': {'name': 'red'...       7         []
# 1    [{'game_index': 9, 'version': {'name': 'red', ...      10         []
# 2    [{'game_index': 154, 'version': {'name': 'red'...      20         []
# 3    [{'game_index': 176, 'version': {'name': 'red'...       6         []
# 4    [{'game_index': 178, 'version': {'name': 'red'...      11         []
# ..                                                 ...     ...        ...
# 893                                                 []      12         []
# 894                                                 []      21         []
# 895                                                 []      22         []
# 896                                                 []      20         []
# 897                                                 []      11         []
#
#       id  is_default                          location_area_encounters  \
# 0      1        True    https://pokeapi.co/api/v2/pokemon/1/encounters
# 1      2        True    https://pokeapi.co/api/v2/pokemon/2/encounters
# 2      3        True    https://pokeapi.co/api/v2/pokemon/3/encounters
# 3      4        True    https://pokeapi.co/api/v2/pokemon/4/encounters
# 4      5        True    https://pokeapi.co/api/v2/pokemon/5/encounters
# ..   ...         ...                                               ...
# 893  894        True  https://pokeapi.co/api/v2/pokemon/894/encounters
# 894  895        True  https://pokeapi.co/api/v2/pokemon/895/encounters
# 895  896        True  https://pokeapi.co/api/v2/pokemon/896/encounters
# 896  897        True  https://pokeapi.co/api/v2/pokemon/897/encounters
# 897  898        True  https://pokeapi.co/api/v2/pokemon/898/encounters
#
#                                                  moves        name  ...  \
# 0    [{'move': {'name': 'razor-wind', 'url': 'https...   bulbasaur  ...
# 1    [{'move': {'name': 'swords-dance', 'url': 'htt...     ivysaur  ...
# 2    [{'move': {'name': 'swords-dance', 'url': 'htt...    venusaur  ...
# 3    [{'move': {'name': 'mega-punch', 'url': 'https...  charmander  ...
# 4    [{'move': {'name': 'mega-punch', 'url': 'https...  charmeleon  ...
# ..                                                 ...         ...  ...
# 893                                                 []   regieleki  ...
# 894                                                 []   regidrago  ...
# 895                                                 []   glastrier  ...
# 896                                                 []   spectrier  ...
# 897                                                 []     calyrex  ...
#
#                                                species  \
# 0    {'name': 'bulbasaur', 'url': 'https://pokeapi....
# 1    {'name': 'ivysaur', 'url': 'https://pokeapi.co...
# 2    {'name': 'venusaur', 'url': 'https://pokeapi.c...
# 3    {'name': 'charmander', 'url': 'https://pokeapi...
# 4    {'name': 'charmeleon', 'url': 'https://pokeapi...
# ..                                                 ...
# 893  {'name': 'regieleki', 'url': 'https://pokeapi....
# 894  {'name': 'regidrago', 'url': 'https://pokeapi....
# 895  {'name': 'glastrier', 'url': 'https://pokeapi....
# 896  {'name': 'spectrier', 'url': 'https://pokeapi....
# 897  {'name': 'calyrex', 'url': 'https://pokeapi.co...
#
#                                                sprites  \
# 0    {'back_default': 'https://raw.githubuserconten...
# 1    {'back_default': 'https://raw.githubuserconten...
# 2    {'back_default': 'https://raw.githubuserconten...
# 3    {'back_default': 'https://raw.githubuserconten...
# 4    {'back_default': 'https://raw.githubuserconten...
# ..                                                 ...
# 893  {'back_default': 'https://raw.githubuserconten...
# 894  {'back_default': 'https://raw.githubuserconten...
# 895  {'back_default': 'https://raw.githubuserconten...
# 896  {'back_default': 'https://raw.githubuserconten...
# 897  {'back_default': 'https://raw.githubuserconten...
#
#                                                  stats  \
# 0    [{'base_stat': 45, 'effort': 0, 'stat': {'name...
# 1    [{'base_stat': 60, 'effort': 0, 'stat': {'name...
# 2    [{'base_stat': 80, 'effort': 0, 'stat': {'name...
# 3    [{'base_stat': 39, 'effort': 0, 'stat': {'name...
# 4    [{'base_stat': 58, 'effort': 0, 'stat': {'name...
# ..                                                 ...
# 893  [{'base_stat': 80, 'effort': 0, 'stat': {'name...
# 894  [{'base_stat': 200, 'effort': 3, 'stat': {'nam...
# 895  [{'base_stat': 100, 'effort': 0, 'stat': {'nam...
# 896  [{'base_stat': 100, 'effort': 0, 'stat': {'nam...
# 897  [{'base_stat': 100, 'effort': 3, 'stat': {'nam...
#
#                                                  types weight        ABILITY1  \
# 0    [{'slot': 1, 'type': {'name': 'grass', 'url': ...     69        overgrow
# 1    [{'slot': 1, 'type': {'name': 'grass', 'url': ...    130        overgrow
# 2    [{'slot': 1, 'type': {'name': 'grass', 'url': ...   1000        overgrow
# 3    [{'slot': 1, 'type': {'name': 'fire', 'url': '...     85           blaze
# 4    [{'slot': 1, 'type': {'name': 'fire', 'url': '...    190           blaze
# ..                                                 ...    ...             ...
# 893  [{'slot': 1, 'type': {'name': 'electric', 'url...   1450      transistor
# 894  [{'slot': 1, 'type': {'name': 'dragon', 'url':...   2000     dragons-maw
# 895  [{'slot': 1, 'type': {'name': 'ice', 'url': 'h...   8000  chilling-neigh
# 896  [{'slot': 1, 'type': {'name': 'ghost', 'url': ...    445      grim-neigh
# 897  [{'slot': 1, 'type': {'name': 'psychic', 'url'...     77         unnerve
#
#      ABILITY2 HIDDEN_ABILITY     TYPE1   TYPE2
# 0        none    chlorophyll     grass  poison
# 1        none    chlorophyll     grass  poison
# 2        none    chlorophyll     grass  poison
# 3        none    solar-power      fire    none
# 4        none    solar-power      fire    none
# ..        ...            ...       ...     ...
# 893      none           none  electric    none
# 894      none           none    dragon    none
# 895      none           none       ice    none
# 896      none           none     ghost    none
# 897      none           none   psychic   grass
#
# [898 rows x 22 columns]

# %%
df_poke_ab_type = df_poke_ab_type.drop(columns = "types")

# %%
df_poke_ab_type
# Out:
#      base_experience                                              forms  \
# 0                 64  [{'name': 'bulbasaur', 'url': 'https://pokeapi...
# 1                142  [{'name': 'ivysaur', 'url': 'https://pokeapi.c...
# 2                236  [{'name': 'venusaur', 'url': 'https://pokeapi....
# 3                 62  [{'name': 'charmander', 'url': 'https://pokeap...
# 4                142  [{'name': 'charmeleon', 'url': 'https://pokeap...
# ..               ...                                                ...
# 893              290  [{'name': 'regieleki', 'url': 'https://pokeapi...
# 894              290  [{'name': 'regidrago', 'url': 'https://pokeapi...
# 895              290  [{'name': 'glastrier', 'url': 'https://pokeapi...
# 896              290  [{'name': 'spectrier', 'url': 'https://pokeapi...
# 897              250  [{'name': 'calyrex', 'url': 'https://pokeapi.c...
#
#                                           game_indices  height held_items  \
# 0    [{'game_index': 153, 'version': {'name': 'red'...       7         []
# 1    [{'game_index': 9, 'version': {'name': 'red', ...      10         []
# 2    [{'game_index': 154, 'version': {'name': 'red'...      20         []
# 3    [{'game_index': 176, 'version': {'name': 'red'...       6         []
# 4    [{'game_index': 178, 'version': {'name': 'red'...      11         []
# ..                                                 ...     ...        ...
# 893                                                 []      12         []
# 894                                                 []      21         []
# 895                                                 []      22         []
# 896                                                 []      20         []
# 897                                                 []      11         []
#
#       id  is_default                          location_area_encounters  \
# 0      1        True    https://pokeapi.co/api/v2/pokemon/1/encounters
# 1      2        True    https://pokeapi.co/api/v2/pokemon/2/encounters
# 2      3        True    https://pokeapi.co/api/v2/pokemon/3/encounters
# 3      4        True    https://pokeapi.co/api/v2/pokemon/4/encounters
# 4      5        True    https://pokeapi.co/api/v2/pokemon/5/encounters
# ..   ...         ...                                               ...
# 893  894        True  https://pokeapi.co/api/v2/pokemon/894/encounters
# 894  895        True  https://pokeapi.co/api/v2/pokemon/895/encounters
# 895  896        True  https://pokeapi.co/api/v2/pokemon/896/encounters
# 896  897        True  https://pokeapi.co/api/v2/pokemon/897/encounters
# 897  898        True  https://pokeapi.co/api/v2/pokemon/898/encounters
#
#                                                  moves        name  ...  \
# 0    [{'move': {'name': 'razor-wind', 'url': 'https...   bulbasaur  ...
# 1    [{'move': {'name': 'swords-dance', 'url': 'htt...     ivysaur  ...
# 2    [{'move': {'name': 'swords-dance', 'url': 'htt...    venusaur  ...
# 3    [{'move': {'name': 'mega-punch', 'url': 'https...  charmander  ...
# 4    [{'move': {'name': 'mega-punch', 'url': 'https...  charmeleon  ...
# ..                                                 ...         ...  ...
# 893                                                 []   regieleki  ...
# 894                                                 []   regidrago  ...
# 895                                                 []   glastrier  ...
# 896                                                 []   spectrier  ...
# 897                                                 []     calyrex  ...
#
#      past_types                                            species  \
# 0            []  {'name': 'bulbasaur', 'url': 'https://pokeapi....
# 1            []  {'name': 'ivysaur', 'url': 'https://pokeapi.co...
# 2            []  {'name': 'venusaur', 'url': 'https://pokeapi.c...
# 3            []  {'name': 'charmander', 'url': 'https://pokeapi...
# 4            []  {'name': 'charmeleon', 'url': 'https://pokeapi...
# ..          ...                                                ...
# 893          []  {'name': 'regieleki', 'url': 'https://pokeapi....
# 894          []  {'name': 'regidrago', 'url': 'https://pokeapi....
# 895          []  {'name': 'glastrier', 'url': 'https://pokeapi....
# 896          []  {'name': 'spectrier', 'url': 'https://pokeapi....
# 897          []  {'name': 'calyrex', 'url': 'https://pokeapi.co...
#
#                                                sprites  \
# 0    {'back_default': 'https://raw.githubuserconten...
# 1    {'back_default': 'https://raw.githubuserconten...
# 2    {'back_default': 'https://raw.githubuserconten...
# 3    {'back_default': 'https://raw.githubuserconten...
# 4    {'back_default': 'https://raw.githubuserconten...
# ..                                                 ...
# 893  {'back_default': 'https://raw.githubuserconten...
# 894  {'back_default': 'https://raw.githubuserconten...
# 895  {'back_default': 'https://raw.githubuserconten...
# 896  {'back_default': 'https://raw.githubuserconten...
# 897  {'back_default': 'https://raw.githubuserconten...
#
#                                                  stats weight        ABILITY1  \
# 0    [{'base_stat': 45, 'effort': 0, 'stat': {'name...     69        overgrow
# 1    [{'base_stat': 60, 'effort': 0, 'stat': {'name...    130        overgrow
# 2    [{'base_stat': 80, 'effort': 0, 'stat': {'name...   1000        overgrow
# 3    [{'base_stat': 39, 'effort': 0, 'stat': {'name...     85           blaze
# 4    [{'base_stat': 58, 'effort': 0, 'stat': {'name...    190           blaze
# ..                                                 ...    ...             ...
# 893  [{'base_stat': 80, 'effort': 0, 'stat': {'name...   1450      transistor
# 894  [{'base_stat': 200, 'effort': 3, 'stat': {'nam...   2000     dragons-maw
# 895  [{'base_stat': 100, 'effort': 0, 'stat': {'nam...   8000  chilling-neigh
# 896  [{'base_stat': 100, 'effort': 0, 'stat': {'nam...    445      grim-neigh
# 897  [{'base_stat': 100, 'effort': 3, 'stat': {'nam...     77         unnerve
#
#     ABILITY2 HIDDEN_ABILITY     TYPE1   TYPE2
# 0       none    chlorophyll     grass  poison
# 1       none    chlorophyll     grass  poison
# 2       none    chlorophyll     grass  poison
# 3       none    solar-power      fire    none
# 4       none    solar-power      fire    none
# ..       ...            ...       ...     ...
# 893     none           none  electric    none
# 894     none           none    dragon    none
# 895     none           none       ice    none
# 896     none           none     ghost    none
# 897     none           none   psychic   grass
#
# [898 rows x 21 columns]

# %% [markdown]
# ## Task 4: Save Local File

# %% [markdown]
# I save a local csv file that has been edited.

# %%
df_poke_ab_type.to_csv("301_all_pokemon_data_edit.csv", index=False)
df_poke_ab_type.shape
# Out:
# (898, 21)
